# %% [markdown]
# ****Lab1 - codes from the book****

# %% [markdown]
# ### 1.1 Computing with language: Texts and Words

# %%
import nltk

# %%
 from nltk.book import*

# %% [markdown]
# #### `concordance` permits us to see words in context.

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text1.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text2.similar("monstrous")
# Out:
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly

# %% [markdown]
# #### `common_contexts` allows us to examine the context that are shared bytwo or more words.

# %%
text2.common_contexts(["monstrous", "very" ])
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad

# %%
text2.similar("sense")
# Out:
# sister that side as opinion mother means time marianne wish want part
# sweetness resolution and family property manner life but

# %% [markdown]
# #### Plotting `dispersion plot`

# %%
text4.dispersion_plot(["citiens", "democracy", "freedom", "duties", "America"])

# %%
text3.generate()
# Out:
# Building ngram index...
# laid by her , and said unto Cain , Where art thou , and said , Go to ,
# I will not do it for ten ' s sons ; we dreamed each man according to
# their generatio the firstborn said unto Laban , Because I said , Nay ,
# but Sarah shall her name be . , duke Elah , duke Shobal , and Akan .
# and looked upon my affliction . Bashemath Ishmael ' s blood , but Isra
# for as a prince hast thou found of all the cattle in the valley , and
# the wo The
# "laid by her , and said unto Cain , Where art thou , and said , Go to ,\nI will not do it for ten ' s sons ; we dreamed each man according to\ntheir generatio the firstborn said unto Laban , Because I said , Nay ,\nbut Sarah shall her name be . , duke Elah , duke Shobal , and Akan .\nand looked upon my affliction . Bashemath Ishmael ' s blood , but Isra\nfor as a prince hast thou found of all the cattle in the valley , and\nthe wo The"

# %% [markdown]
# #### counting vocabulary

# %%
len(text3)
# Out:
# 44764

# %% [markdown]
# #### sorted list of vocabulary items,  beginning with various punctuation symbols and continuing with words starting with A

# %%
sorted(set(text3))
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %%
#how many each word is used on average
len(text3)/ len(set(text3))
# Out:
# 16.050197203298673

# %% [markdown]
# #### how often a word occurs in a text

# %%
text3.count("smote")
# Out:
# 5

# %%
100* text4.count('a')/ len(text4)
# Out:
# 1.457973123627309

# %%
text5.count("lol")
# Out:
# 704

# %%
100 * text5.count('lol')/ len(text5)
# Out:
# 1.5640968673628082

# %%
def lexical_diversity(text):
    return len(text)/ len(set(text))
def percentage(count, total):
    return 100* count/total

# %%
lexical_diversity(text3)
# Out:
# 16.050197203298673

# %%
print(lexical_diversity(text4))
percentage(text4.count('a'), len(text4))
# Out:
# 15.111167154241905
# 1.457973123627309

# %%
print(lexical_diversity(text5))
percentage(text5.count('the'), len(text5))
# Out:
# 7.420046158918563
# 1.4352366140857586

# %% [markdown]
# ### Texts as Lists of Words

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
len(sent1)
# Out:
# 4

# %%
lexical_diversity(sent1)
# Out:
# 1.0

# %%
student = ['Ekta', 'Chaudhary', 'loves', 'pizza']

# %%
student
# Out:
# ['Ekta', 'Chaudhary', 'loves', 'pizza']

# %%
len(student)
# Out:
# 4

# %%
lexical_diversity(student)
# Out:
# 1.0

# %%
len(set(student))
# Out:
# 4

# %%
student.count('loves')
# Out:
# 1

# %%
sent1 + sent2
# Out:
# ['Call',
#  'me',
#  'Ishmael',
#  '.',
#  'The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
sent1.append("Ekta")
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.', 'Ekta']

# %%
text4[174]
# Out:
# 'in'

# %%
text4.index('awaken')
# Out:
# 173

# %%
text5[16715:16735]
# Out:
# ['U86',
#  'thats',
#  'why',
#  'something',
#  'like',
#  'gamefly',
#  'is',
#  'so',
#  'good',
#  'because',
#  'you',
#  'can',
#  'actually',
#  'play',
#  'a',
#  'full',
#  'game',
#  'without',
#  'buying',
#  'it']

# %%
sent =  ['word1', 'word2', 'word3', 'word4', 'word5', 'word6', 'word7', 'word8', 'word9', 'word10']

# %%
sent[0]
# Out:
# 'word1'

# %%
sent[5:8]
# Out:
# ['word6', 'word7', 'word8']

# %%
sent[:3]
# Out:
# ['word1', 'word2', 'word3']

# %%
text2[141525:]
# Out:
# ['among',
#  'the',
#  'merits',
#  'and',
#  'the',
#  'happiness',
#  'of',
#  'Elinor',
#  'and',
#  'Marianne',
#  ',',
#  'let',
#  'it',
#  'not',
#  'be',
#  'ranked',
#  'as',
#  'the',
#  'least',
#  'considerable',
#  ',',
#  'that',
#  'though',
#  'sisters',
#  ',',
#  'and',
#  'living',
#  'almost',
#  'within',
#  'sight',
#  'of',
#  'each',
#  'other',
#  ',',
#  'they',
#  'could',
#  'live',
#  'without',
#  'disagreement',
#  'between',
#  'themselves',
#  ',',
#  'or',
#  'producing',
#  'coolness',
#  'between',
#  'their',
#  'husbands',
#  '.',
#  'THE',
#  'END']

# %%
my_sent= ['She', 'was', 'as', 'kind', 'hearted', 'person', 'with', 'evil' 'minded', 'brain']

# %%
noun_phrase = my_sent[1:4]

# %%
noun_phrase
# Out:
# ['was', 'as', 'kind']

# %%
words = sorted(noun_phrase)

# %%
words
# Out:
# ['as', 'kind', 'was']

# %%
vocab = set(text1)

# %%
vocab_size = len(vocab)

# %%
vocab_size
# Out:
# 19317

# %%
name = 'Ekta'
name[0]
# Out:
# 'E'

# %%
name * 2
# Out:
# 'EktaEkta'

# %%
name + '!'
# Out:
# 'Ekta!'

# %%
' '.join(['Ekta', 'Chaudhary'])
# Out:
# 'Ekta Chaudhary'

# %%
'Ekta Chaudhary'.split()
# Out:
# ['Ekta', 'Chaudhary']

# %% [markdown]
# ### 1.3 Computing with Language: Simple Statics

# %%
saying = ['After', 'all', 'is', 'said', 'and', 'done', 'more', 'is', 'said', 'this', 'holds']

# %%
tokens = set(saying)

# %%
tokens = sorted(tokens)

# %%
tokens[-2:]
# Out:
# ['said', 'this']

# %% [markdown]
# ****Frequncy Distributions****

# %%
from nltk.book import *

# %%
fdist1 = FreqDist(text1)

# %%
fdist1
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
vocabulary1 = fdist1.keys()

# %%
vocabulary1
# Out:
# dict_keys(['[', 'Moby', 'Dick', 'by', 'Herman', 'Melville', '1851', ']', 'ETYMOLOGY', '.', '(', 'Supplied', 'a', 'Late', 'Consumptive', 'Usher', 'to', 'Grammar', 'School', ')', 'The', 'pale', '--', 'threadbare', 'in', 'coat', ',', 'heart', 'body', 'and', 'brain', ';', 'I', 'see', 'him', 'now', 'He', 'was', 'ever', 'dusting', 'his', 'old', 'lexicons', 'grammars', 'with', 'queer', 'handkerchief', 'mockingly', 'embellished', 'all', 'the', 'gay', 'flags', 'of', 'known', 'nations', 'world', 'loved', 'dust', 'it', 'somehow', 'mildly', 'reminded', 'mortality', '"', 'While', 'you', 'take', 'hand', 'school', 'others', 'teach', 'them', 'what', 'name', 'whale', '-', 'fish', 'is', 'be', 'called', 'our', 'tongue', 'leaving', 'out', 'through', 'ignorance', 'letter', 'H', 'which', 'almost', 'alone', 'maketh', 'signification', 'word', 'deliver', 'that', 'not', 'true', '."', 'HACKLUYT', 'WHALE', '...', 'Sw', 'Dan', 'HVAL', 'This', 'animal', 'named', 'from', 'roundness', 'or', 'rolling', 'for', 'HVALT
# ...

# %%
fdist1['whale']
# Out:
# 906

# %%
fdist2= FreqDist(text2)

# %%
fdist2
# Out:
# FreqDist({',': 9397, 'to': 4063, '.': 3975, 'the': 3861, 'of': 3565, 'and': 3350, 'her': 2436, 'a': 2043, 'I': 2004, 'in': 1904, ...})

# %%
vocabulary2 = fdist2.keys()

# %%
vocabulary2
# Out:
# dict_keys(['[', 'Sense', 'and', 'Sensibility', 'by', 'Jane', 'Austen', '1811', ']', 'CHAPTER', '1', 'The', 'family', 'of', 'Dashwood', 'had', 'long', 'been', 'settled', 'in', 'Sussex', '.', 'Their', 'estate', 'was', 'large', ',', 'their', 'residence', 'at', 'Norland', 'Park', 'the', 'centre', 'property', 'where', 'for', 'many', 'generations', 'they', 'lived', 'so', 'respectable', 'a', 'manner', 'as', 'to', 'engage', 'general', 'good', 'opinion', 'surrounding', 'acquaintance', 'late', 'owner', 'this', 'single', 'man', 'who', 'very', 'advanced', 'age', 'years', 'his', 'life', 'constant', 'companion', 'housekeeper', 'sister', 'But', 'her', 'death', 'which', 'happened', 'ten', 'before', 'own', 'produced', 'great', 'alteration', 'home', ';', 'supply', 'loss', 'he', 'invited', 'received', 'into', 'house', 'nephew', 'Mr', 'Henry', 'legal', 'inheritor', 'person', 'whom', 'intended', 'bequeath', 'it', 'In', 'society', 'niece', 'children', 'old', 'Gentleman', "'", 's', 'days', 'were', 'comfort
# ...

# %%
fdist1.plot(50, cumulative = True);

# %%
# Words occuring only once, hapaxes i.e unique
fdist1.hapaxes()
# Out:
# ['Herman',
#  'Melville',
#  ']',
#  'ETYMOLOGY',
#  'Late',
#  'Consumptive',
#  'School',
#  'threadbare',
#  'lexicons',
#  'mockingly',
#  'flags',
#  'mortality',
#  'signification',
#  'HACKLUYT',
#  'Sw',
#  'HVAL',
#  'roundness',
#  'Dut',
#  'Ger',
#  'WALLEN',
#  'WALW',
#  'IAN',
#  'RICHARDSON',
#  'KETOS',
#  'GREEK',
#  'CETUS',
#  'LATIN',
#  'WHOEL',
#  'ANGLO',
#  'SAXON',
#  'WAL',
#  'HWAL',
#  'SWEDISH',
#  'ICELANDIC',
#  'BALEINE',
#  'BALLENA',
#  'FEGEE',
#  'ERROMANGOAN',
#  'Librarian',
#  'painstaking',
#  'burrower',
#  'grub',
#  'Vaticans',
#  'stalls',
#  'higgledy',
#  'piggledy',
#  'gospel',
#  'promiscuously',
#  'commentator',
#  'belongest',
#  'sallow',
#  'Pale',
#  'Sherry',
#  'loves',
#  'bluntly',
#  'Subs',
#  'thankless',
#  'Hampton',
#  'Court',
#  'hie',
#  'refugees',
#  'pampered',
#  'Michael',
#  'Raphael',
#  'unsplinterable',
#  'GENESIS',
#  'JOB',
#  'JONAH',
#  'punish',
#  'ISAIAH',
#  'soever',
#  'cometh',
# ...

# %% [markdown]
# #### Fine-Grained Selection of Words

# %%
V= set(text1)

# %%
V
# Out:
# {'wall',
#  'swinging',
#  'Curse',
#  'dismally',
#  'imps',
#  'brilliant',
#  'Herman',
#  'openly',
#  'gazing',
#  'Porpoise',
#  'planets',
#  'mock',
#  'clashing',
#  'shudder',
#  'abasement',
#  'hospitals',
#  'handling',
#  'down',
#  'failed',
#  'curved',
#  'About',
#  'primary',
#  'mumbled',
#  'spherical',
#  'Wall',
#  'Make',
#  'reviewed',
#  'excepting',
#  'sex',
#  'mizentop',
#  'scrolled',
#  'depressed',
#  'comprehensively',
#  'soothes',
#  'tropics',
#  'peeping',
#  'clammy',
#  'pox',
#  'analysed',
#  'nomenclature',
#  'impregnated',
#  'flapped',
#  'planted',
#  'studious',
#  'drives',
#  'inclement',
#  'May',
#  'floods',
#  'Says',
#  'simultaneously',
#  'epidemic',
#  'fencing',
#  'falsified',
#  'roared',
#  'sinners',
#  'gloomy',
#  'belaying',
#  'diameter',
#  'signal',
#  'landed',
#  'almost',
#  'rumbled',
#  'Hence',
#  'Ain',
#  'counted',
#  'dines',
#  'desperado',
#  '33',
#  'unfaltering',
#  'careful',
#  'Dame',
#  'DO',
# ...

# %%
# words that are more than 15 characters long
long_words = [w for w in V if len(w) > 15]

# %%
sorted(long_words)
# Out:
# ['CIRCUMNAVIGATION',
#  'Physiognomically',
#  'apprehensiveness',
#  'cannibalistically',
#  'characteristically',
#  'circumnavigating',
#  'circumnavigation',
#  'circumnavigations',
#  'comprehensiveness',
#  'hermaphroditical',
#  'indiscriminately',
#  'indispensableness',
#  'irresistibleness',
#  'physiognomically',
#  'preternaturalness',
#  'responsibilities',
#  'simultaneousness',
#  'subterraneousness',
#  'supernaturalness',
#  'superstitiousness',
#  'uncomfortableness',
#  'uncompromisedness',
#  'undiscriminating',
#  'uninterpenetratingly']

# %%
long_word1 = [word for word in vocab if len(word) > 15]

# %%
long_word1
# Out:
# ['indiscriminately',
#  'cannibalistically',
#  'circumnavigating',
#  'preternaturalness',
#  'Physiognomically',
#  'comprehensiveness',
#  'responsibilities',
#  'circumnavigation',
#  'uncompromisedness',
#  'superstitiousness',
#  'CIRCUMNAVIGATION',
#  'simultaneousness',
#  'characteristically',
#  'irresistibleness',
#  'uninterpenetratingly',
#  'physiognomically',
#  'subterraneousness',
#  'uncomfortableness',
#  'apprehensiveness',
#  'indispensableness',
#  'hermaphroditical',
#  'circumnavigations',
#  'undiscriminating',
#  'supernaturalness']

# %%
# words from chat corpus that are longer than 7 characters and
#that occurs more than 7 times
fdist5 = FreqDist(text5)

# %%
sorted([w for w in set(text5) if len(w) > 7 and fdist5[w] > 7])
# Out:
# ['#14-19teens',
#  '#talkcity_adults',
#  '((((((((((',
#  '........',
#  'Question',
#  'actually',
#  'anything',
#  'computer',
#  'cute.-ass',
#  'everyone',
#  'football',
#  'innocent',
#  'listening',
#  'remember',
#  'seriously',
#  'something',
#  'together',
#  'tomorrow',
#  'watching']

# %% [markdown]
# #### Collication and Bigrams

# %%
bigrams(['more', 'is', 'said', 'than', 'done']) 
[('more', 'is'), ('is', 'said'), ('said', 'than'), ('than', 'done')]
# Out:
# [('more', 'is'), ('is', 'said'), ('said', 'than'), ('than', 'done')]

# %% [markdown]
# ****Counting other things****

# %%
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
fdist
# Out:
# FreqDist({'.': 1268, 'JOIN': 1021, 'PART': 1016, '?': 737, 'lol': 704, 'to': 658, 'i': 648, 'the': 646, 'you': 635, ',': 596, ...})

# %%
fdist.keys()
# Out:
# dict_keys(['now', 'im', 'left', 'with', 'this', 'gay', 'name', ':P', 'PART', 'hey', 'everyone', 'ah', 'well', 'NICK', ':', 'U7', 'is', 'a', '.', 'ACTION', 'gives', 'U121', 'golf', 'clap', ':)', 'JOIN', 'hi', 'U59', '26', '/', 'm', 'ky', 'women', 'that', 'are', 'nice', 'please', 'pm', 'me', 'there', 'ya', 'go', 'do', "n't", 'fuck', 'you', ':@', 'whats', 'up', 'to', '?', 'i', "'ll", 'thunder', 'your', 'ass', 'and', 'dont', 'even', 'know', 'what', 'means', 'sounds', 'painful', 'any', 'ladis', 'wanna', 'chat', '29', 'my', 'cousin', 'drew', 'messed', 'pic', 'on', 'cast', '24', 'boo', 'sexy', 'lol', 'U115', 'he', 'girl', 'legs', 'spread', 'hope', 'didnt', 'draw', 'penis', 'ewwwww', '&', 'head', 'between', 'her', 'good', 'r', 'u', 'serious', 'I', 'take', 'one', ',', 'have', 'the', 'docs', 'tomorrow', 'man', 'am', 'too', '..', 'Connected', '...', 'Slip', 'away', 'Fade', 'Days', 'Still', 'feel', 'Touching', 'Changing', 'Considerably', 'killing', 'heeeey', '!', 'sharpie', "'re", 'back', 'U129'
# ...

# %%
fdist.items()
# Out:
# dict_items([('now', 79), ('im', 128), ('left', 17), ('with', 152), ('this', 86), ('gay', 30), ('name', 27), (':P', 15), ('PART', 1016), ('hey', 264), ('everyone', 63), ('ah', 8), ('well', 81), ('NICK', 24), (':', 96), ('U7', 119), ('is', 372), ('a', 568), ('.', 1268), ('ACTION', 346), ('gives', 6), ('U121', 36), ('golf', 2), ('clap', 3), (':)', 101), ('JOIN', 1021), ('hi', 546), ('U59', 12), ('26', 10), ('/', 133), ('m', 81), ('ky', 2), ('women', 7), ('that', 274), ('are', 178), ('nice', 52), ('please', 21), ('pm', 108), ('me', 415), ('there', 120), ('ya', 100), ('go', 73), ('do', 168), ("n't", 141), ('fuck', 15), ('you', 635), (':@', 1), ('whats', 41), ('up', 160), ('to', 658), ('?', 737), ('i', 648), ("'ll", 38), ('thunder', 1), ('your', 137), ('ass', 15), ('and', 335), ('dont', 75), ('even', 35), ('know', 103), ('what', 183), ('means', 5), ('sounds', 9), ('painful', 2), ('any', 123), ('ladis', 1), ('wanna', 107), ('chat', 142), ('29', 5), ('my', 242), ('cousin', 2), ('drew', 2), (
# ...

# %%
fdist.max()
# Out:
# '.'

# %%
fdist[3]
# Out:
# 0

# %%
fdist.freq(3)
# Out:
# 0.0

# %%
sent7
# Out:
# ['Pierre',
#  'Vinken',
#  ',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'will',
#  'join',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  'Nov.',
#  '29',
#  '.']

# %%
[w for w in sent7 if len(w) < 4]
# Out:
# [',', '61', 'old', ',', 'the', 'as', 'a', '29', '.']

# %%
[w for w in sent7 if len(w) ==4]
# Out:
# ['will', 'join', 'Nov.']

# %%
sorted([w for w in set(text1) if w.endswith('ableness')])
# Out:
# ['comfortableness',
#  'honourableness',
#  'immutableness',
#  'indispensableness',
#  'indomitableness',
#  'intolerableness',
#  'palpableness',
#  'reasonableness',
#  'uncomfortableness']

# %%
sorted([term for term in set(text4) if 'gnt' in term])
# Out:
# ['Sovereignty', 'sovereignties', 'sovereignty']

# %%
sorted([item for item in set(text6) if item.istitle()])
# Out:
# ['A',
#  'Aaaaaaaaah',
#  'Aaaaaaaah',
#  'Aaaaaah',
#  'Aaaah',
#  'Aaaaugh',
#  'Aaagh',
#  'Aaah',
#  'Aaauggh',
#  'Aaaugh',
#  'Aaauugh',
#  'Aagh',
#  'Aah',
#  'Aauuggghhh',
#  'Aauuugh',
#  'Aauuuuugh',
#  'Aauuuves',
#  'Action',
#  'Actually',
#  'African',
#  'Ages',
#  'Aggh',
#  'Agh',
#  'Ah',
#  'Ahh',
#  'Alice',
#  'All',
#  'Allo',
#  'Almighty',
#  'Alright',
#  'Am',
#  'Amen',
#  'An',
#  'Anarcho',
#  'And',
#  'Angnor',
#  'Anthrax',
#  'Antioch',
#  'Anybody',
#  'Anyway',
#  'Apples',
#  'Aramaic',
#  'Are',
#  'Arimathea',
#  'Armaments',
#  'Arthur',
#  'As',
#  'Ask',
#  'Assyria',
#  'At',
#  'Attila',
#  'Augh',
#  'Autumn',
#  'Auuuuuuuugh',
#  'Away',
#  'Ay',
#  'Ayy',
#  'B',
#  'Back',
#  'Bad',
#  'Badon',
#  'Battle',
#  'Be',
#  'Beast',
#  'Bedevere',
#  'Bedwere',
#  'Behold',
#  'Between',
#  'Beyond',
#  'Black',
#  'Bloody',
#  'Blue',
#  'Bon',
#  'Bones',
#  'Book',
#  'Bors',
#  'Brave',
#  'Bravely',
#  'Bravest',
#  'Bread',
# ...

# %%
sorted([item for item in set(sent7) if item.isdigit()])
# Out:
# ['29', '61']

# %%
sorted([w for w in set(text7) if '-' in w and 'index' in w])
# Out:
# ['Stock-index',
#  'index-arbitrage',
#  'index-fund',
#  'index-options',
#  'index-related',
#  'stock-index']

# %%
sorted([wd for wd in set(text3) if wd.istitle() and len(wd)> 10])
# Out:
# ['Abelmizraim',
#  'Allonbachuth',
#  'Beerlahairoi',
#  'Canaanitish',
#  'Chedorlaomer',
#  'Girgashites',
#  'Hazarmaveth',
#  'Hazezontamar',
#  'Ishmeelites',
#  'Jegarsahadutha',
#  'Jehovahjireh',
#  'Kirjatharba',
#  'Melchizedek',
#  'Mesopotamia',
#  'Peradventure',
#  'Philistines',
#  'Zaphnathpaaneah']

# %%
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
[w.upper() for w in text1]
# Out:
# ['[',
#  'MOBY',
#  'DICK',
#  'BY',
#  'HERMAN',
#  'MELVILLE',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'SUPPLIED',
#  'BY',
#  'A',
#  'LATE',
#  'CONSUMPTIVE',
#  'USHER',
#  'TO',
#  'A',
#  'GRAMMAR',
#  'SCHOOL',
#  ')',
#  'THE',
#  'PALE',
#  'USHER',
#  '--',
#  'THREADBARE',
#  'IN',
#  'COAT',
#  ',',
#  'HEART',
#  ',',
#  'BODY',
#  ',',
#  'AND',
#  'BRAIN',
#  ';',
#  'I',
#  'SEE',
#  'HIM',
#  'NOW',
#  '.',
#  'HE',
#  'WAS',
#  'EVER',
#  'DUSTING',
#  'HIS',
#  'OLD',
#  'LEXICONS',
#  'AND',
#  'GRAMMARS',
#  ',',
#  'WITH',
#  'A',
#  'QUEER',
#  'HANDKERCHIEF',
#  ',',
#  'MOCKINGLY',
#  'EMBELLISHED',
#  'WITH',
#  'ALL',
#  'THE',
#  'GAY',
#  'FLAGS',
#  'OF',
#  'ALL',
#  'THE',
#  'KNOWN',
#  'NATIONS',
#  'OF',
#  'THE',
#  'WORLD',
#  '.',
#  'HE',
#  'LOVED',
#  'TO',
#  'DUST',
#  'HIS',
#  'OLD',
#  'GRAMMARS',
#  ';',
#  'IT',
#  'SOMEHOW',
#  'MILDLY',
#  'REMINDED',
#  'HIM',
#  'OF',
#  'HIS',
#  'MORTALITY',
#  '.',
#  '"',
# ...

# %%
len(set([word.lower() for word in text1]))
# Out:
# 17231

# %%
word = 'cat'
if len(word) < 5:
    print('word length is less than 5')
# Out:
# word length is less than 5

# %%
sent1 = ['Call', 'me', 'Ishmael', '.']
for xyzzy in sent1:
    if xyzzy.endswith('l'):
        print ('xyzzy')
# Out:
# xyzzy
# xyzzy

# %%
for token in sent1:
    if token.islower():
        print (token, 'is a lowercase word')
    elif token.istitle():
        print (token, 'is a titlecase word')
    else:
        print (token, 'is punctuation')
# Out:
# Call is a titlecase word
# me is a lowercase word
# Ishmael is a titlecase word
# . is punctuation

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
tricky = sorted([w for w in set(text2) if 'cie' in w or 'cei' in w])
for word in tricky:
    print(word)
# Out:
# ancient
# ceiling
# conceit
# conceited
# conceive
# conscience
# conscientious
# conscientiously
# deceitful
# deceive
# deceived
# deceiving
# deficiencies
# deficiency
# deficient
# delicacies
# excellencies
# fancied
# insufficiency
# insufficient
# legacies
# perceive
# perceived
# perceiving
# prescience
# prophecies
# receipt
# receive
# received
# receiving
# society
# species
# sufficient
# sufficiently
# undeceive
# undeceiving
